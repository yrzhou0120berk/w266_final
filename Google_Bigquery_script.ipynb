# %%
from google.cloud import bigquery
import pandas as pd

# %%
"""
Before running the script, you will need to CMD and authenticate with 

'gcloud auth application-default login'

"""

# %%
client = bigquery.Client(project='manifest-frame-203601')
# Out:
# /Users/cathyzhou/anaconda3/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
QUERY = (
    """
    select * from w266_final.final_20k
    LIMIT 100""")
query_job = client.query(QUERY)  # API request
rows = query_job.result()  # Waits for query to finish

df = []
for row in rows:
    df.append([row.repo_path,row.c_content])

# %%
df = pd.DataFrame(df)
df.columns = ['repo_path','content']
df
# Out:
#                                             repo_path  \
# 0         watchdogpolska/feder feder/records/types.py
# 1   tomasreimers/tensorflow-emscripten tensorflow/...
# 2   tiagoarasilva/django-boilerplate project_name/...
# 3           softappeal/yass py2/test/contract_test.py
# 4   gcarq/freqtrade freqtrade/tests/test_fiat_conv...
# 5               google/pasta pasta/base/formatting.py
# 6   saebyn/django-classifieds classifieds/sitemaps.py
# 7   devilry/devilry-django devilry/devilry_compres...
# 8   pyrocko/pyrocko src/gui/snufflings/seismosizer.py
# 9      erigones/esdc-ce api/dc/storage/serializers.py
# 10                  moddevices/mod-ui mod/settings.py
# 11  4degrees/lucidity test/fixture/template/mount_...
# 12    ms-iot/python cpython/Tools/unicode/gencodec.py
# 13  tensorflow/models research/mlperf_object_detec...
# 14  openstack/tempest tempest/api/identity/v2/test...
# 15   flammified/terrabot terrabot/packets/packet39.py
# 16     lukasmonk/lucaschess Code/QT/PantallaConfig.py
# 17  coreGreenberet/homematicip-rest-api tests/json...
# 18  MetaMetricsInc/django-static-version example/e...
# 19                                 maas/maas setup.py
# 20  cloudera/hue desktop/core/ext-py/urllib3-1.22/...
# 21   betterlife/psi psi/app/views/product_category.py
# 22  the-zebulan/CodeWars tests/kyu_8_tests/test_co...
# 23  enigmagroup/enigmabox-openwrt webinterface/fil...
# 24             cfce/chilin chilin2/modules/ceas/dc.py
# 25  fasiondog/hikyuu tools/hikyuu/interactive/kauf...
# 26        paxswill/evesrp src/evesrp/util/datetime.py
# 27            Intuity/Tktr ticketing/api/api_login.py
# 28   intel-iot-devkit/upm examples/python/loudness.py
# 29  mattbernst/polyhartree support/ansible/modules...
# ..                                                ...
# 70  openstack/solum solum/tests/api/controllers/v1...
# 71  theheros/kbengine kbe/res/scripts/common/Lib/t...
# 72   capstone-coal/pycoal pycoal/tests/mining_test.py
# 73  isb-cgc/examples-Python python/pairwise/pairwi...
# 74       hcs64/vgm_ripping demux/FWSEconv/FWSEconv.py
# 75               abusesa/idiokit idiokit/http/date.py
# 76  svenkreiss/pysparkling pysparkling/fileio/code...
# 77  beiko-lab/gengis bin/Lib/site-packages/wx-2.8-...
# 78  golismero/golismero tools/sqlmap/plugins/dbms/...
# 79  liminspace/django-transtool tests/tests/test_c...
# 80  svn2github/chromium-depot-tools third_party/bo...
# 81          jbalogh/zamboni apps/editors/sql_table.py
# 82  ezScrum/ezScrum robotTesting/keywords/lib/Sele...
# 83  jctanner/ansible lib/ansible/modules/network/a...
# 84           pyrocko/pyrocko src/obspy_compat/base.py
# 85      pandas-dev/pandas pandas/core/reshape/melt.py
# 86  piqueserver/piqueserver tests/pyspades/test_pr...
# 87             dgobbi/vtk-dicom Utilities/parsetpl.py
# 88         rocky/python3-trepan trepan/lib/deparse.py
# 89  zestedesavoir/Python-ZMarkdown tests/test_exte...
# 90         vim-awesome/vim-awesome db/github_repos.py
# 91  aceofwings/Evt-Gateway gateway/tests/core/sdo/...
# 92  LPgenerator/django-db-mailer dbmail/providers/...
# 93  xuleiboy1234/autoTitle tensorflow/tensorflow/p...
# 94  jctanner/ansible lib/ansible/modules/network/f...
# 95  hpcugent/easybuild-framework test/framework/in...
# 96  huaxz1986/git_book chapters/Kaggle/grid_search.py
# 97                    codesy/codesy payments/views.py
# 98  hgascon/pulsar pulsar/core/sippy/UasStateTryin...
# 99          CartoDB/carto-python carto/file_import.py
#
#                                               content
# 0   from abc import abstractmethod, ABCMeta\n\n\nc...
# 1   # Copyright 2016 The TensorFlow Authors. All R...
# 2   from django.http import HttpResponseForbidden,...
# 3   import unittest\nfrom typing import Any\n\nimp...
# 4   # pragma pylint: disable=missing-docstring, to...
# 5   # coding=utf-8\n"""Operations for storing and ...
# 6   """\n"""\nfrom django.contrib.sitemaps import ...
# 7   # -*- coding: utf-8 -*-\n# Generated by Django...
# 8   import numpy as num\nimport os\n\nfrom pyrocko...
# 9   from api import serializers as s\nfrom vms.mod...
# 10  # -*- coding: utf-8 -*-\n\n# Copyright 2012-20...
# 11  # :coding: utf-8\n# :copyright: Copyright (c) ...
# 12  """ Unicode Mapping Parser and Codec Generator...
# 13  # Generated by the protocol buffer compiler.  ...
# 14  # Copyright 2015 OpenStack Foundation.\n# Copy...
# 15  import struct\n\n\nclass Packet39Parser(object...
# 16  from PyQt4 import QtCore\n\nfrom Code import D...
# 17  from tests.json_data.plugable_switch_measuring...
# 18  """\nDjango settings for example project.\n\nG...
# 19  # Copyright 2012-2016 Canonical Ltd.  This sof...
# 20  from urllib3._collections import (\n    HTTPHe...
# 21  # coding=utf-8\nfrom psi.app.models import Pro...
# 22  import unittest\n\nfrom katas.kyu_8.count_by_x...
# 23  """\nWSGI config for cnc project.\n\nThis modu...
# 24  """\nDC version of ceas\n"""\nfrom samflow.com...
# 25  #!/usr/bin/python\n# -*- coding: utf8 -*-\n# c...
# 26  from __future__ import absolute_import\n\nimpo...
# 27  import logging\nfrom pyramid.httpexceptions im...
# 28  #!/usr/bin/env python\n# Author: Jon Trulson <...
# 29  #!/usr/bin/python\n\nDOCUMENTATION = """\nmodu...
# ..                                                ...
# 70  # Copyright 2013 - Red Hat, Inc.\n#\n# License...
# 71  import unittest\r\nfrom test import support\r\...
# 72  # Copyright (C) 2017-2018 COAL Developers\n#\n...
# 73  '''\nCopyright 2015, Institute for Systems Bio...
# 74  #!/usr/bin/python\n\nfrom io import open\nfrom...
# 75  import time\n\n\n_WEEKDAYS = ["Mon", "Tue", "W...
# 76  from __future__ import absolute_import\n\nimpo...
# 77  #---------------------------------------------...
# 78  #!/usr/bin/env python\n\n"""\nCopyright (c) 20...
# 79  # coding=utf-8\nimport os\nfrom django.conf im...
# 80  # Copyright (c) 2010 Mitch Garnaat http://garn...
# 81  from django.core.exceptions import FieldError\...
# 82  #!/usr/bin/python\n# -*- coding: utf-8 -*-\nfr...
# 83  #!/usr/bin/python\n#\n# @author: Gaurav Rastog...
# 84  # http://pyrocko.org - GPLv3\n#\n# The Pyrocko...
# 85  # pylint: disable=E1101,E1103\n# pylint: disab...
# 86  """\ntest pyspades/protocol.py\n"""\n\nfrom tw...
# 87  """\nParse one of Dave Clunie's tpl files and ...
# 88  # -*- coding: utf-8 -*-\n'''Deparsing Routines...
# 89  """\nPython-Markdown Extension Regression Test...
# 90  """A table of all known GitHub repos of vim pl...
# 91  # import unittest\n# import os\n# from gateway...
# 92  from dbmail.providers.microsoft.base import MP...
# 93  # Copyright 2017 The TensorFlow Authors. All R...
# 94  #!/usr/bin/python\n# -*- coding: utf-8 -*-\n#\...
# 95  # #\n# Copyright 2013-2018 Ghent University\n#...
# 96  import  scipy\nfrom sklearn.ensemble import Gr...
# 97  import urllib\n\nfrom django.views.generic imp...
# 98  # Copyright (c) 2003-2005 Maxim Sobolev. All r...
# 99  """\nModule for importing remote and local fil...
#
# [100 rows x 2 columns]
