# %%
from google.cloud import bigquery
import pandas as pd
import ast
import glove_helper
import tensorflow as tf
import numpy as np

from itertools import groupby
from os.path import basename, splitext
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
# Out:
# /home/andrew_mamroth/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Before running the script, you will need to CMD and authenticate with
#
# 'gcloud auth application-default login'

# %%
client = bigquery.Client(project='manifest-frame-203601')
# Out:
# /home/andrew_mamroth/anaconda3/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
QUERY = (
    """
    select * from w266_final.final_20k
    LIMIT 1000""")
query_job = client.query(QUERY)  # API request
rows = query_job.result()  # Waits for query to finish

df = []
for row in rows:
    df.append([row.repo_path,row.c_content])

# %%
df = pd.DataFrame(df)
df.columns = ['repo_path','content']
df
# Out:
#                                              repo_path  \
# 0          watchdogpolska/feder feder/records/types.py
# 1            softappeal/yass py2/test/contract_test.py
# 2    gcarq/freqtrade freqtrade/tests/test_fiat_conv...
# 3    devilry/devilry-django devilry/devilry_compres...
# 4       erigones/esdc-ce api/dc/storage/serializers.py
# 5                    moddevices/mod-ui mod/settings.py
# 6      ms-iot/python cpython/Tools/unicode/gencodec.py
# 7     flammified/terrabot terrabot/packets/packet39.py
# 8       lukasmonk/lucaschess Code/QT/PantallaConfig.py
# 9    MetaMetricsInc/django-static-version example/e...
# 10                                  maas/maas setup.py
# 11   enigmagroup/enigmabox-openwrt webinterface/fil...
# 12              cfce/chilin chilin2/modules/ceas/dc.py
# 13    intel-iot-devkit/upm examples/python/loudness.py
# 14   mattbernst/polyhartree support/ansible/modules...
# 15   Kulbear/deep-learning-nano-foundation DLND-tv-...
# 16   Hackerfleet/hfos modules/countables/hfos/count...
# 17          iBluemind/armatis armatis/parsers/epost.py
# 18        bzero/bitex libs/autobahn/tests/test_wamp.py
# 19         ohmu/pglookout test/test_cluster_monitor.py
# 20   openstack/neutron-fwaas neutron_fwaas/tests/fu...
# 21   Southpaw-TACTIC/TACTIC src/pyasm/security/auth...
# 22   ellmetha/django-machina machina/templatetags/f...
# 23    exercism/python exercises/hello-world/example.py
# 24          memsql/memsql-python memsql/common/util.py
# 25   general-language-syntax/GLS test/integration/F...
# 26   miguelgrinberg/python-socketio socketio/namesp...
# 27     practicalswift/bitcoin share/rpcauth/rpcauth.py
# 28                  BillBarry/pyqwc pyqwc/clientlib.py
# 29   eleweek/WatchPeopleCode migrations/versions/55...
# ..                                                 ...
# 970  proxysh/Safejumper-for-Desktop buildmac/Resour...
# 971  mEDI-S/mEDI_s-Elite-Tools elite/loader/eddn/dy...
# 972            viraintel/OWASP-Nettacker core/parse.py
# 973          joschu/rapprentice test/tps_unit_tests.py
# 974  lafranceinsoumise/api-django agir/webhooks/vie...
# 975          wsmorgan/analyzefit tests/test_analyze.py
# 976              antidot/Pyckson src/pyckson/parser.py
# 977  manahl/PythonTrainingExercises Beginners/strin...
# 978                          hacklabr/timtec manage.py
# 979  leapcode/soledad src/leap/soledad/client/_db/b...
# 980   richardkiss/pycoin pycoin/contrib/msg_signing.py
# 981     jrxFive/python-nomad tests/test_deployments.py
# 982   kobolabs/calibre src/calibre/utils/soupparser.py
# 983         apache/allura Allura/allura/model/types.py
# 984                132nd-etcher/EMFT emft/core/sltp.py
# 985                tek/amino amino/anon/prod/method.py
# 986       oilshell/oil opy/_regtest/src/asdl/encode.py
# 987              mfichman/winbrew formula/portaudio.py
# 988                     tbabej/roots profiles/views.py
# 989  olange/learning-mongodb course-m101p/hw2-3-use...
# 990  nschneid/pysupersensetagger src/pyutil/corpus/...
# 991        Soliel/WriggleBot Scripts/Cogs/PetBattle.py
# 992  e-gob/plataforma-kioscos-autoatencion scripts/...
# 993  SectorLabs/django-localized-fields localized_f...
# 994               ltalirz/asetk scripts/qe-plot-sts.py
# 995                  ac1235/core ai_templates/crazy.py
# 996    linkedin/iris src/iris/webhooks/alertmanager.py
# 997  TaskEvolution/Task-Coach-Evolution taskcoach/t...
# 998            OstapHEP/ostap ostap/math/random_ext.py
# 999  anhstudios/swganh data/scripts/templates/objec...
#
#                                                content
# 0    from abc import abstractmethod, ABCMeta\n\n\nc...
# 1    import unittest\nfrom typing import Any\n\nimp...
# 2    # pragma pylint: disable=missing-docstring, to...
# 3    # -*- coding: utf-8 -*-\n# Generated by Django...
# 4    from api import serializers as s\nfrom vms.mod...
# 5    # -*- coding: utf-8 -*-\n\n# Copyright 2012-20...
# 6    """ Unicode Mapping Parser and Codec Generator...
# 7    import struct\n\n\nclass Packet39Parser(object...
# 8    from PyQt4 import QtCore\n\nfrom Code import D...
# 9    """\nDjango settings for example project.\n\nG...
# 10   # Copyright 2012-2016 Canonical Ltd.  This sof...
# 11   """\nWSGI config for cnc project.\n\nThis modu...
# 12   """\nDC version of ceas\n"""\nfrom samflow.com...
# 13   #!/usr/bin/env python\n# Author: Jon Trulson <...
# 14   #!/usr/bin/python\n\nDOCUMENTATION = """\nmodu...
# 15   import numpy as np\nimport tensorflow as tf\nf...
# 16   #!/usr/bin/env python\n# -*- coding: UTF-8 -*-...
# 17   # -*- coding: utf-8 -*-\n\nfrom armatis.models...
# 18   ##############################################...
# 19   """\npglookout\n\nCopyright (c) 2015 Ohmu Ltd\...
# 20   # Copyright 2015 Red Hat, Inc.\n#\n#    Licens...
# 21   ##############################################...
# 22   # -*- coding: utf-8 -*-\n\nfrom __future__ imp...
# 23          def hello():\n    return 'Hello, World!'\n
# 24   def timedelta_total_seconds(td):\n    """ Need...
# 25                       #\ndef aaa():\n    # ...\n#\n
# 26   class Namespace(object):\n    """Base class fo...
# 27   #!/usr/bin/env python3\n# Copyright (c) 2015-2...
# 28   import walrus\nimport uuid\nfrom configobj imp...
# 29   """empty message\n\nRevision ID: 552800b5e708\...
# ..                                                 ...
# 970  # Copyright (c) Twisted Matrix Laboratories.\n...
# 971  # -*- coding: UTF8\r\n'''\r\nCreated on 28.09....
# 972  #!/usr/bin/env python\n# -*- coding: utf-8 -*-...
# 973  \nfrom rapprentice import testing, tps\nimport...
# 974  import json\n\nimport requests\nfrom django.ut...
# 975  """Tests the manipulation of the data used in ...
# 976  from pyckson.model.helpers import ModelProvide...
# 977  """With this string:\n'monty pythons flying ci...
# 978  #!/usr/bin/env python\nimport os\nimport sys\n...
# 979  # -*- coding: utf-8 -*-\n# sync.py\n# Copyrigh...
# 980  import io\nimport re\n\nfrom binascii import b...
# 981  import pytest\nimport os\n\n\n# integration te...
# 982  __doc__ = """External interface to the Beautif...
# 983  #       Licensed to the Apache Software Founda...
# 984  # coding=utf-8\n"""Simple Lua Python Parser"""...
# 985  import operator\nfrom typing import Any, Calla...
# 986  """\nencode.py\n"""\n\nfrom asdl import asdl_ ...
# 987  \nimport winbrew\n\nclass Portaudio(winbrew.Fo...
# 988  from django.contrib import messages\nfrom djan...
# 989  # -*- coding: UTF8 -*-\n\n#\n# Copyright (c) 2...
# 990  # coding=UTF-8\n'''\nHandles the 'integrated' ...
# 991  import sqlalchemy\nimport discord\nimport rand...
# 992  #!/usr/bin/python\n# -*- coding: utf-8 -*-\n\n...
# 993  from typing import List, Union\n\nfrom django ...
# 994  #!/usr/bin/env python\nfrom __future__ import ...
# 995  \nimport random\n\n# CoRe\ndef turn(board, sym...
# 996  from __future__ import absolute_import\n\nimpo...
# 997  '''\nTask Coach - Your friendly task manager\n...
# 998  #!/usr/bin/env python\n# -*- coding: utf-8 -*-...
# 999  #### NOTICE: THIS FILE IS AUTOGENERATED\n#### ...
#
# [1000 rows x 2 columns]

# %%
def cleanup(docstring_list):
    
    """takes a list of doc strings and converts to a single flat list of tokens"""
    
    tokens = [tf.keras.preprocessing.text.text_to_word_sequence(i) for i in docstring_list]
    flat_tokens = [item for sublist in tokens for item in sublist]
    flat_string = " ".join(flat_tokens)
    
    return flat_string

def get_docstrings(source):
    
    """function to walk through parse tree and return list of docstrings"""
    
    NODE_TYPES = {
    ast.ClassDef: 'Class',
    ast.FunctionDef: 'Function/Method',
    ast.Module: 'Module'
    }
    
    docstrings = []
    
    try:
        tree = ast.parse(source)
    except:
        return " "
       
    for node in ast.walk(tree):
        if isinstance(node, tuple(NODE_TYPES)):
            docstring = ast.get_docstring(node)
            docstrings.append(docstring)
    
    docstrings =  [x for x in docstrings if x is not None]
    clean_string = cleanup(docstrings)
            
    return clean_string

# %%
df['docstrings'] = [get_docstrings(x) for x in list(df['content'])]

# %%
hands = glove_helper.Hands(ndim=100)
# Out:
# Loading vectors from data/glove/glove.6B.zip
# Parsing file: data/glove/glove.6B.zip:glove.6B.100d.txt
# Found 400,000 words.
# Parsing vectors... Done! (W.shape = (400003, 100))

# %%
#Set up corpus for count vectorizer
corpus = list(df['docstrings'])

#count values for tfidf calculations
count_vect = CountVectorizer()
count_vect = count_vect.fit(corpus)
freq_term_matrix = count_vect.transform(corpus)

#generate idf scores
tfidf = TfidfTransformer(norm="l2")
tfidf.fit(freq_term_matrix)

#to grab columns for words
vocab = count_vect.vocabulary_

def sent_to_embed(sentence):
    
    """converts a sentence to the average of it's tfidf weighted word embedding vectors"""
    
    if len(sentence)==0:
        return np.zeros(100)
    
    global vocab, count_vect, tfidf
    
    doc_freq_term = count_vect.transform([sentence])
    idfs = tfidf.transform(doc_freq_term)
    sent_list = sentence.split(" ")
    embeddings = []
    
    for i in range(len(sent_list)):
        
        if sent_list[i] in vocab:
            
            col = vocab[sent_list[i]]
            embed = hands.get_vector(sent_list[i], strict=False)
            tfidf = idfs[0, col]
            embeddings.append(np.multiply(embed, tfidf))
    
    embed_array = np.asarray(embeddings)
        
    return np.mean(embed_array, axis=0)

# %%
doc = corpus[4]
print(sent_to_embed(doc))
print(corpus[4])

for x in list(df['docstrings']):
    print(sent_to_embed(x).shape)
# Out:
# [ 0.0234355   0.22777049 -0.0171718  -0.0553103   0.0016924  -0.07032032
#   0.0743405   0.05483138  0.03267015 -0.08054673  0.08635088  0.15677272
#   0.29848596  0.00899725  0.08804607 -0.06751103  0.12732211  0.17513788
#   0.23478861 -0.0958536  -0.08928827 -0.18141979  0.11200067  0.21903269
#  -0.02076004 -0.12438046  0.0974158   0.00058226 -0.04466866  0.08916865
#   0.08171917  0.14848487 -0.23854826 -0.07286189  0.30173206 -0.00879507
#   0.09035531 -0.02529267  0.12300045 -0.24701552 -0.00617683 -0.07225616
#  -0.10411046  0.19979866 -0.00975291  0.09237226 -0.059384   -0.10374748
#  -0.0994691   0.1631269  -0.00237415  0.04395526 -0.06288457  0.07528418
#   0.24503791  0.0820905   0.04279137 -0.04692107  0.06633011 -0.00681209
#  -0.1287261   0.01459729 -0.16214044  0.22237132  0.02553525  0.09783664
#  -0.09344202 -0.32609722  0.09482899  0.01330843  0.00610403  0.08294348
#  -0.04318903  0.01845386 -0.13952835 -0.01660035  0.18413396  0.16456003
#   0.05464598 -0.17527129  0.11942548 -0.14637512 -0.01854467  0.11551249
#  -0.10043833  0.16276516  0.14659058 -0.04363927 -0.1868807  -0.06658985
#   0.13137858  0.15313672  0.06954839 -0.13027422  0.16185448 -0.12099785
#  -0.16023086 -0.1310692   0.21149446 -0.02837907]
# vms models nodestorage
# (100,)
# (100,)
# (100,)
# (100,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-75d3f79626eb> in <module>()
#       4
#       5 for x in list(df['docstrings']):
# ----> 6     print(sent_to_embed(x).shape)
#
# <ipython-input-12-16e7fa4a2fd3> in sent_to_embed(sentence)
#      24
#      25     doc_freq_term = count_vect.transform([sentence])
# ---> 26     idfs = tfidf.transform(doc_freq_term)
#      27     sent_list = sentence.split(" ")
#      28     embeddings = []
#
# AttributeError: 'numpy.float64' object has no attribute 'transform'
